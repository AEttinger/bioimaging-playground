# %%
# %matplotlib inline
import numpy
import cv
import matplotlib
# option 1: matplotlib.use('nbagg') # option 2: write 'backend: nbagg' into ~/.matplotlib/matplotlibrc
from matplotlib import pyplot as plt

from skimage import data,io

# %%
test = data.coins()

# %%
io.imshow(test)
io.show()
